# %%
#importing dependencies

import os
import re
import database
import numpy as np
import pandas as pd
from datetime import datetime
from tabulate import tabulate

# %%
def runApplication():
    print('Select Which Query to run')
    print('''
Query 1:
Hospital Information according to Zip code, with Google Maps location.
    
Query 2:
Giving all information available for Covid cases in a particular county and date range.

Query 3:
First shows the NAICS Code and its description then asks the user choose the NAICS code.
Then Giving a list of all hospitals with address for a particular NAICS code and ZIP code.

Query 4:
The date a hospital was last reviewed in a particular zip code
''')
    choice = None
    while True:
        choice = int(input("Enter the option you would like to access"))

# %%
if __name__ == "__main__":
#     query = database.databaseQueries()
    print('''Welcome to Exploring Hospital and COVID-19 Data Application''')
    while True:
        choice = None
        print('''
To Login Press 1
                 
For Registration Press 2
                ''')
        try:
            choice = int(input())
            if choice == 1:
#                 query.login()
                runApplication()
                break
                
            elif choice == 2:
#                 query.register()
#                 query.login()
                runApplication()
                break
            else:
                print('Incorrect Choice')
                continue
                
        except Exception as error:
            print ("Oops! An exception has occured:", error)
            print ("Exception TYPE:", type(error))
# Out:
# Welcome to Exploring Hospital and COVID-19 Data Application
#
# To Login Press 1
#
# For Registration Press 2
#
# 1
# Select Which Query to run
#
# Query 1:
# Hospital Information according to Zip code, with Google Maps location.
#
# Query 2:
# Giving all information available for Covid cases in a particular county and date range.
#
# Query 3:
# First shows the NAICS Code and its description then asks the user choose the NAICS code.
# Then Giving a list of all hospitals with address for a particular NAICS code and ZIP code.
#
# Query 4:
# The date a hospital was last reviewed in a particular zip code
#
#
# Enter the option you would like to access4
# Enter the option you would like to access
# Oops! An exception has occured: invalid literal for int() with base 10: ''
# Exception TYPE: <class 'ValueError'>
#
# To Login Press 1
#
# For Registration Press 2
#
#
# Oops! An exception has occured: invalid literal for int() with base 10: ''
# Exception TYPE: <class 'ValueError'>
#
# To Login Press 1
#
# For Registration Press 2
#
#
# Oops! An exception has occured: invalid literal for int() with base 10: ''
# Exception TYPE: <class 'ValueError'>
#
# To Login Press 1
#
# For Registration Press 2
